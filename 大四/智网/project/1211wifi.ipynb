# %%
# -*- coding:utf-8 -*-
import os

def set_wifi_ssid_psk(ssid, psk):
    os.system('sudo wpa_cli -i wlan0 set_network 0 ssid ' + '\'"' + ssid + '"\'')
    os.system('sudo wpa_cli -i wlan0 set_network 0 psk ' + '\'"' + psk + '"\'')
    os.system('sudo wpa_cli -i wlan0 enable_network 0')
    os.system('sudo wpa_cli -i wlan0 save_config')

def scan_wifi():
    # 搜索附近的wifi
    os.system('wpa_cli -i wlan0 scan')
    # 显示搜索wifi热点的结果
    str = os.popen('wpa_cli -i wlan0 scan_result')
    return str
    
# def main():
#     # set_wifi_ssid_psk('ssid_set_by_python', 'psk_set_by_python')


# if __name__ == '__main__':
#     main()



r=scan_wifi()
info = r.readlines()
tmp = 0
for line in info:
    line = line.strip('\r\n')
    mac = line[0:17]
   # print(line)
   # if mac == '74:60:fa:81:a8:d8':
    if mac == '30:7b:ac:08:32:8c':  
        print(line)
#     tmp +=1
#     if tmp==2:
#         break

# mac = line[0:17]
# rssi = line[23:26]
# Out:
# bssid / frequency / signal level / flags / ssid
# 66:6e:97:6d:24:9f	2437	-61	[WPA-PSK-CCMP][WPA2-PSK-CCMP][ESS]
# 64:6e:97:7d:3b:ce	2437	-61	[WPA-PSK-CCMP][WPA2-PSK-CCMP][ESS]	robot_connection
# 30:7b:ac:08:32:80	5785	-50	[WPA2-EAP-CCMP][ESS]	eduroam
# 30:7b:ac:08:32:87	5785	-50	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 30:7b:ac:08:32:8c	5785	-51	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:08:32:8c	5785	-51	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:08:32:96	2462	-41	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 30:7b:ac:08:32:9b	2462	-42	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:08:32:90	2462	-44	[WPA2-EAP-CCMP][ESS]	eduroam
# 30:7b:ac:09:6c:76	2437	-55	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 30:7b:ac:09:6c:7b	2437	-56	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:09:6c:70	2437	-57	[WPA2-EAP-CCMP][ESS]	eduroam
# 30:7b:ac:40:86:56	2412	-63	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 30:7b:ac:40:86:50	2412	-63	[WPA2-EAP-CCMP][ESS]	eduroam
# d0:76:e7:81:2f:cf	2462	-66	[WPA-PSK-CCMP][WPA2-PSK-CCMP][ESS]	418A_sc
# 30:7b:ac:08:62:5b	2412	-67	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:08:62:56	2412	-68	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 76:40:bb:7c:ca:0b	2462	-69	[WPA2-PSK-CCMP][WPS][ESS][P2P]	DIRECT-0b-HP M227f LaserJet
# 66:6e:97:6d:3b:d0	5785	-80	[WPA-PSK-CCMP][WPA2-PSK-CCMP][ESS]
# 30:7b:ac:09:6c:60	5765	-74	[WPA2-EAP-CCMP][ESS]	eduroam
# 30:7b:ac:09:6c:67	5765	-74	[WPA2-EAP-CCMP][ESS]	Tsinghua-IPv6-SAVA
# 30:7b:ac:09:6c:6c	5765	-74	[WPA2-EAP-CCMP][ESS]	Tsinghua-Secure
# 30:7b:ac:08:62:50	2412	-71	[WPA2-EAP-CCMP][ESS]	eduroam
# 64:6e:97:7d:3b:d0	5785	-81	[WPA-PSK-CCMP][WPA2-PSK-CCMP][ESS]	robot_connection
# 5c:63:bf:c9:47:86	2412	-80	[WPA-PSK-CCMP][WPA2-PSK-CCMP][WPS][ESS]	thuzz
# 06:0e:3c:74:03:18	2412	-75	[WPA2-PSK-CCMP][ESS][P2P]	DIRECT-18-HP Laser 136w
# 30:7b:ac:08:63:20	5785	-83	[WPA2-EAP-CCMP][ESS]	eduroam
# d8:5d:4c:73:49:6a	2437	-20	[WEP][ESS]	MERCURY_73496A
# 30:7b:ac:08:32:81	5785	-50	[ESS]	Tsinghua-Guest
# 30:7b:ac:08:32:82	5785	-50	[ESS]	Tsinghua-Visitor
# 30:7b:ac:08:32:83	5785	-50	[ESS]	DIVI
# 30:7b:ac:08:32:84	5785	-50	[ESS]	DIVI-2
# 30:7b:ac:08:32:89	5785	-50	[ESS]	Tsinghua-\xe6\x97\xa0\xe7\xba\xbf\xe7\xbd\x91\xe4\xbd\xbf\xe7\x94\xa8\xe8\xaf\xb4\xe6\x98\x8e
# 30:7b:ac:08:32:8a	5785	-50	[ESS]	Tsinghua-IPv4
# 30:7b:ac:08:32:8b	5785	-50	[ESS]	Tsinghua-IPv6
# 30:7b:ac:08:32:85	5785	-51	[ESS]	IVI
# 30:7b:ac:08:32:94	2462	-42	[ESS]	IVI
# 30:7b:ac:08:32:9a	2462	-43	[ESS]	Tsinghua-IPv6
# 30:7b:ac:08:32:91	2462	-43	[ESS]	Tsinghua-Guest
# 30:7b:ac:08:32:92	2462	-43	[ESS]	Tsinghua-Visitor
# 30:7b:ac:08:32:98	2462	-44	[ESS]	Tsinghua-\xe6\x97\xa0\xe7\xba\xbf\xe7\xbd\x91\xe4\xbd\xbf\xe7\x94\xa8\xe8\xaf\xb4\xe6\x98\x8e
# 30:7b:ac:08:32:99	2462	-44	[ESS]	Tsinghua-IPv4
# 30:7b:ac:08:32:93	2462	-45	[ESS]	DIVI
# 30:7b:ac:09:6c:73	2437	-56	[ESS]	DIVI
# 30:7b:ac:09:6c:7a	2437	-56	[ESS]	Tsinghua-IPv6
# 30:7b:ac:09:6c:71	2437	-56	[ESS]	Tsinghua-Guest
# 30:7b:ac:09:6c:74	2437	-57	[ESS]	IVI
# 30:7b:ac:09:6c:72	2437	-57	[ESS]	Tsinghua-Visitor
# 30:7b:ac:09:6c:78	2437	-57	[ESS]	Tsinghua-\xe6\x97\xa0\xe7\xba\xbf\xe7\xbd\x91\xe4\xbd\xbf\xe7\x94\xa8\xe8\xaf\xb4\xe6\x98\x8e
# 30:7b:ac:09:6c:79	2437	-57	[ESS]	Tsinghua-IPv4
# 30:7b:ac:40:86:59	2412	-60	[ESS]	Tsinghua-IPv4
# 30:7b:ac:40:86:54	2412	-63	[ESS]	IVI
# 30:7b:ac:40:86:5a	2412	-63	[ESS]	Tsinghua-IPv6
# 30:7b:ac:40:86:51	2412	-63	[ESS]	Tsinghua-Guest
# 30:7b:ac:92:f2:71	2437	-65	[ESS]	Tsinghua-Guest
# 30:7b:ac:92:f2:72	2437	-66	[ESS]	Tsinghua-Visitor
# 30:7b:ac:92:f2:73	2437	-67	[ESS]	DIVI
# 30:7b:ac:08:62:5a	2412	-68	[ESS]	Tsinghua-IPv6
# 30:7b:ac:08:62:59	2412	-69	[ESS]	Tsinghua-IPv4
# 30:7b:ac:08:62:51	2412	-70	[ESS]	Tsinghua-Guest
# 30:7b:ac:08:62:52	2412	-70	[ESS]	Tsinghua-Visitor
# 30:7b:ac:08:62:53	2412	-70	[ESS]	DIVI
# 30:7b:ac:09:6c:61	5765	-74	[ESS]	Tsinghua-Guest
# 30:7b:ac:09:6c:62	5765	-74	[ESS]	Tsinghua-Visitor
# 30:7b:ac:09:6c:63	5765	-74	[ESS]	DIVI
# 30:7b:ac:09:6c:65	5765	-74	[ESS]	IVI
# 30:7b:ac:09:6c:69	5765	-74	[ESS]	Tsinghua-\xe6\x97\xa0\xe7\xba\xbf\xe7\xbd\x91\xe4\xbd\xbf\xe7\x94\xa8\xe8\xaf\xb4\xe6\x98\x8e
# 30:7b:ac:09:6c:6a	5765	-74	[ESS]	Tsinghua-IPv4
# 30:7b:ac:09:6c:6b	5765	-74	[ESS]	Tsinghua-IPv6
# 30:7b:ac:09:6c:64	5765	-74	[ESS]	DIVI-2
# 30:7b:ac:08:62:54	2412	-71	[ESS]	IVI
